# %%
import csv
import math

###Setup###
#Creating IDs
#with open("insurance.csv", 'r') as input, open('temp.csv', 'w') as output:
#    reader = csv.reader(input, delimiter = ',')
#    writer = csv.writer(output, delimiter = ',')
#
#    all = []
#    row = next(reader)
#    row.insert(0, 'ID')
#    all.append(row)
#    count = 0
#    for row in reader:
#        count += 1
#        row.insert(0, count)
#        all.append(row)
#    writer.writerows(all)


#Making lists with the data

ID = []
age = []
sex = []
bmi = []
children = []
smoker = []
region = []
charges = []

with open('temp.csv', 'r') as insurance_file:
    reader = csv.DictReader(insurance_file)
    insurance_file_dictionary = {}
    for row in reader:
        #print(row)
        ID.append(row['ID'])
        age.append(row['age'])
        sex.append(row['sex'])
        bmi.append(row['bmi'])
        children.append(row['children'])
        smoker.append(row['smoker'])
        region.append(row['region'])
        charges.append(row['charges'])
#print(charges)

#Making dictionary with the data

def insurance_dictionary(ID, age, sex, bmi, children, smoker, region, charges):
    list_len = len(ID)
    insurance_dictionary = {}
    for index in range(list_len):
        insurance_dictionary[ID[index]] = {'ID': ID[index],
                                           'Age': age[index],
                                           'Sex': sex[index],
                                           'BMI': bmi[index],
                                           'Children': children[index],
                                           'Smoker': smoker[index],
                                           'Region': region[index],
                                           'Charges': charges[index]
                                           }
    return insurance_dictionary

insurance_dictionary = insurance_dictionary(ID, age, sex, bmi, children, smoker, region, charges)
#print(insurance_dictionary)

###Full data calculations###




#Class calculations:
class Calculations:
    
    def __init__(self, data, name):
        self.data = data
        self.name = name

    def minimum_data(self, data):
        minimum_data = 9999999999999
        for datus in self.data:
           if float(datus) < minimum_data:
               minimum_data = float(datus)
        return minimum_data
    
    def maximum_data(self, data):
        maximum_data = 0
        for datus in self.data:
            if float(datus) > maximum_data:
                maximum_data = float(datus)
        return maximum_data
    
    def average_data(self, data):
        total_data = 0
        for datus in self.data:
            total_data += float(datus)
        average_data = round(total_data / len(self.data))
        return average_data
        
    def print_all_calculations(self):
        print("This dataset has a {name} minimum of {minimum}, a maximum of {maximum} and an average of {average}.".format(name = self.name, minimum = self.minimum_data(self.data), maximum = self.maximum_data(self.data), average = self.average_data(self.data)))
        
                       
age_calculations = Calculations(age, "age")
#age_calculations.print_all_calculations()

bmi_calculations = Calculations(bmi, "bmi")
#bmi_calculations.print_all_calculations()

charges_calculations = Calculations(charges, "charges")
#charges_calculations.print_all_calculations()

children_calculations = Calculations(children, "children")
#children_calculations.print_all_calculations()


#Sorted data lists:

sorted_age = sorted(age)
sorted_bmi = sorted(bmi, key=float)
#print(sorted_bmi)

sorted_charges = sorted(charges, key=float)

#Sex data in the full dataset:
#print(sex)
def counting_sex(sex):
    male = 0
    female = 0
    for gender in sex:
        if gender == 'male':
            male += 1
        if gender == 'female':
            female += 1
    print("There are {malenum} males and {femalenum} females in this dataset.".format(malenum = male, femalenum = female))

#sex_data = counting_sex(sex)
#print(sex_data)
        

#Smokers data in full dataset:
#print(smoker)

def counting_smokers(smoker):
    smokers_total = 0
    num_people = len(smoker)
    for smokers in smoker:
        if smokers == 'no':
            continue
        elif smokers == 'yes':
            smokers_total += 1
    smokers_percentage = round((smokers_total / num_people) * 100)
    return "There are {smokersnum} smokers over {peoplenum} people, or {percent} per cent.".format(smokersnum = smokers_total, peoplenum = num_people, percent = smokers_percentage)

smokers_data = counting_smokers(smoker)
#print(smokers_data)

#print(sorted_age)


###Region calculations###


#Region count

#print(region)
def region_count(region_sample):
    southwest_temp = 0
    southeast_temp = 0
    northwest_temp = 0
    northeast_temp = 0
    for regions in region_sample:
        if regions == 'southwest':
            southwest_temp += 1
        elif regions == 'southeast':
            southeast_temp += 1
        elif regions == 'northwest':
            northwest_temp += 1
        elif regions == 'northeast':
            northeast_temp += 1   
    return "There are {SWcount} people from the Southwest, {SEcount} from the Southeast, {NWcount} from the Northwest and {NEcount} from the Northeast.".format(SWcount = southwest_temp, SEcount = southeast_temp, NWcount = northwest_temp, NEcount = northeast_temp)





#Region categorisation

southwest = {}
southeast = {}
northwest = {}
northeast = {}


def region_cat(insurance_dictionary):
    for ide in insurance_dictionary:
        region = insurance_dictionary[ide]['Region']
        current_ide = insurance_dictionary[ide]        
        if region == 'southwest':
            southwest.update({ide: insurance_dictionary[ide]})
        elif region == 'southeast':
            southeast.update({ide: insurance_dictionary[ide]})
        elif region == 'northwest':
            northwest.update({ide: insurance_dictionary[ide]})
        elif region == 'northeast':
            northeast.update({ide: insurance_dictionary[ide]})
    return southwest, southeast, northwest, northeast


southwest, southeast, northwest, northeast = region_cat(insurance_dictionary)
#print(southwest)
#len(southwest)
#len(southeast)
#len(northwest)
#len(northeast)

#Data lists per region

class RegionalLists:
    def __init__(self, region_dictionary):
        self.region_dictionary = region_dictionary
    
    def get_age(self, region_dictionary):
        regional_age = []
        for line in self.region_dictionary:
            regional_age.append(self.region_dictionary[line]['Age'])
        return regional_age
    
    def get_bmi(self, region_dictionary):
        regional_bmi = []
        for line in self.region_dictionary:
            regional_bmi.append(self.region_dictionary[line]['BMI'])
        return regional_bmi
    
    def get_children(self, region_dictionary):
        regional_children = []
        for line in self.region_dictionary:
            regional_children.append(self.region_dictionary[line]['Children'])
        return regional_children
    
    def get_charges(self, region_dictionary):
        regional_charges = []
        for line in self.region_dictionary:
            regional_charges.append(self.region_dictionary[line]['Charges'])
        return regional_charges
    
    def get_smokers(self, region_dictionary):
        regional_smokers = []
        for line in self.region_dictionary:
            regional_smokers.append(self.region_dictionary[line]['Smoker'])
        return regional_smokers
    
    def get_sex(self, region_dictionary):
        regional_sex = []
        for line in self.region_dictionary:
            regional_sex.append(self.region_dictionary[line]['Sex'])
        return regional_sex
    
    def get_region(self, region_dictionary):
        region_list = []
        for line in self.region_dictionary:
            region_list.append(self.region_dictionary[line]['Region'])
        return region_list

    
#Southwest data lists    

southwest_calculations = RegionalLists(southwest)
southwest_bmi = southwest_calculations.get_bmi(southwest)
#print(southwest_bmi)
#len(southwest_bmi)
southwest_age = southwest_calculations.get_age(southwest)
#print(southwest_age)
#print(len(southwest_age))
southwest_children = southwest_calculations.get_children(southwest)
#print(southwest_children)
#len(southwest_children)
southwest_charges = southwest_calculations.get_charges(southwest)
#print(southwest_charges)
#len(southwest_charges)
southwest_smokers = southwest_calculations.get_smokers(southwest)
#print(southwest_smokers)
southwest_sex = southwest_calculations.get_sex(southwest)
#print(southwest_sex)


#Southeast data lists

southeast_calculations = RegionalLists(southeast)
southeast_age = southeast_calculations.get_age(southeast)
#print(southeast_age)
#len(southeast_age)        
southeast_bmi = southeast_calculations.get_bmi(southeast)
#print(southeast_bmi)
#len(southeast_bmi)
southeast_children = southeast_calculations.get_children(southeast)
#print(southeast_children)
#len(southeast_children)
southeast_charges = southeast_calculations.get_charges(southeast)
#print(southeast_charges)
#len(southeast_charges)
southeast_smokers = southeast_calculations.get_smokers(southeast)
#print(southeast_smokers)
#len(southeast_smokers)
southeast_sex = southeast_calculations.get_sex(southeast)
#print(southeast_sex)


#Northwest data lists

northwest_calculations = RegionalLists(northwest)
northwest_age = northwest_calculations.get_age(northwest)
#print(northwest_age)
#len(northwest_age)
northwest_bmi = northwest_calculations.get_bmi(northwest)
#print(northwest_bmi)
#len(northwest_bmi)
northwest_children = northwest_calculations.get_children(northwest)
#print(northwest_children)
#len(northwest_children)
northwest_charges = northwest_calculations.get_charges(northwest)
#print(northwest_charges)
#len(northwest_charges)
northwest_smokers = northwest_calculations.get_smokers(northwest)
#print(northwest_smokers)
northwest_sex = northwest_calculations.get_sex(northwest)
#print(northwest_sex)


#Northeast data lists

northeast_calculations = RegionalLists(northeast)
northeast_age = northeast_calculations.get_age(northeast)
#print(northeast_age)
#print(len(northeast_age))
northeast_bmi = northeast_calculations.get_bmi(northeast)
#print(northeast_bmi)
#len(northeast_bmi)
northeast_children = northeast_calculations.get_children(northeast)
#print(northeast_children)
#len(northeast_children)
northeast_charges = northeast_calculations.get_charges(northeast)
#print(northeast_charges)
#len(northeast_charges)
northeast_smokers = northeast_calculations.get_smokers(northeast)
#print(northeast_smokers)
northeast_sex = northeast_calculations.get_sex(northeast)
#print(northeast_sex)



#Age calculations per region:

southwest_age_calculations = Calculations(southwest_age, "Southwest age")
#southwest_age_calculations.print_all_calculations()
southeast_age_calculations = Calculations(southeast_age, "Southeast age")
#southeast_age_calculations.print_all_calculations()
northwest_age_calculations = Calculations(northwest_age, "Northwest age")
#northwest_age_calculations.print_all_calculations()
northeast_age_calculations = Calculations(northeast_age, "Northeast age")
#northeast_age_calculations.print_all_calculations()


#BMI calculations per region

southwest_bmi_calculations = Calculations(southwest_bmi, "Southwest BMI")
#southwest_bmi_calculations.print_all_calculations()
southeast_bmi_calculations = Calculations(southeast_bmi, "Southeast BMI")
#southeast_bmi_calculations.print_all_calculations()
northwest_bmi_calculations = Calculations(northwest_bmi, "Northwest BMI")
#northwest_bmi_calculations.print_all_calculations()
northeast_bmi_calculations = Calculations(northeast_bmi, "Northeast BMI")
#northeast_bmi_calculations.print_all_calculations()


#Children calculations per region

southwest_children_calculations = Calculations(southwest_children, "Southwest children")
#southwest_children_calculations.print_all_calculations()
southeast_children_calculations = Calculations(southeast_children, "Southeast children")
#southeast_children_calculations.print_all_calculations()
northwest_children_calculations = Calculations(northwest_children, "Northwest children")
#northwest_children_calculations.print_all_calculations()
northeast_children_calculations = Calculations(northeast_children, "Northeast children")
#northeast_children_calculations.print_all_calculations()


#Charges calculations per region

southwest_charges_calculations = Calculations(southwest_charges, "Southwest charges")
#southwest_charges_calculations.print_all_calculations()
southeast_charges_calculations = Calculations(southeast_charges, "Southeast charges")
#southeast_charges_calculations.print_all_calculations()
northwest_charges_calculations = Calculations(northwest_charges, "Northwest charges")
#northwest_charges_calculations.print_all_calculations()
northeast_charges_calculations = Calculations(northeast_charges, "Northeast charges")
#northeast_charges_calculations.print_all_calculations()


#Sex data per region

#sex_data_southwest = counting_sex(southwest_sex)
#print(sex_data_southwest)
#sex_data_southeast = counting_sex(southeast_sex)
#print(sex_data_southeast)
#sex_data_northwest = counting_sex(northwest_sex)
#print(sex_data_northwest)
#sex_data_northeast = counting_sex(northeast_sex)
#print(sex_data_northeast)


#Smokers data per region

smokers_data_southwest = counting_smokers(southwest_smokers)
#print(smokers_data_southwest)
smokers_data_southeast = counting_smokers(southeast_smokers)
#print(smokers_data_southeast)
smokers_data_northwest = counting_smokers(northwest_smokers)
#print(smokers_data_northwest)
smokers_data_northeast = counting_smokers(northeast_smokers)
#print(smokers_data_northeast)

#Sorted data lists per region:
#Southwest
sorted_southwest_age = sorted(southwest_age)
sorted_southwest_bmi = sorted(southwest_bmi, key=float)
sorted_southwest_charges = sorted(southwest_charges, key=float)

#Southeast
sorted_southeast_age = sorted(southeast_age)
sorted_southeast_bmi = sorted(southeast_bmi, key=float)
sorted_southeast_charges = sorted(southeast_charges, key=float)
#Northwest
sorted_northwest_age = sorted(northwest_age)
sorted_northwest_bmi = sorted(northwest_bmi, key=float)
sorted_northwest_charges = sorted(northwest_charges, key=float)
#Northeast
sorted_northeast_age = sorted(northeast_age)
sorted_northeast_bmi = sorted(northeast_bmi, key=float)
sorted_northeast_charges = sorted(northeast_charges, key=float)



###Sex Calculations###
#Categorise by sex:
#print(sex)

male = {}
female = {}

def categorise_by_sex(insurance_dictionary):    
    for rank in insurance_dictionary:
        sexes = insurance_dictionary[rank]['Sex']  
        if sexes == 'male':
            male.update({rank: insurance_dictionary[rank]})
        elif sexes == 'female':
            female.update({rank: insurance_dictionary[rank]})
    return male, female

male, female = categorise_by_sex(insurance_dictionary)

#print(male)
#len(male)
#len(female)
    
#Male lists using RegionalLists class
male_lists = RegionalLists(male)
male_age = male_lists.get_age(male)
#print(male_age)
sorted_male_age = sorted(male_age)
#print(sorted_male_age)
male_bmi = male_lists.get_bmi(male)
sorted_male_bmi = sorted(male_bmi, key=float)
#print(sorted_male_bmi)
male_children = male_lists.get_children(male)
#print(male_children)
sorted_male_children = sorted(male_children)
male_smoker = male_lists.get_smokers(male)
male_region = male_lists.get_region(male)
male_charges = male_lists.get_charges(male)
sorted_male_charges = sorted(male_charges, key=float)
#print(sorted_male_charges)

#Female lists
female_lists = RegionalLists(female)
female_age = female_lists.get_age(female)
#print(female_age)
sorted_female_age = sorted(female_age)
#print(sorted_female_age)
female_bmi = female_lists.get_bmi(female)
sorted_female_bmi = sorted(female_bmi, key=float)
#print(sorted_female_bmi)
female_children = female_lists.get_children(female)
#print(female_children)
sorted_female_children = sorted(female_children)
female_smoker = female_lists.get_smokers(female)
female_region = female_lists.get_region(female)
female_charges = female_lists.get_charges(female)
sorted_female_charges = sorted(female_charges, key=float)
#print(sorted_female_charges)


#Calculations:

male_age_calc = Calculations(male_age, 'Male age')
#male_age_calc.print_all_calculations()
male_bmi_calc = Calculations(male_bmi, 'Male BMI')
#male_bmi_calc.print_all_calculations()
male_children_calc = Calculations(male_children, 'Male children')
#male_children_calc.print_all_calculations()
male_smokers_count = counting_smokers(male_smoker)
#print(male_smokers_count)
male_charges_count = Calculations(male_charges, 'Male charges')
#male_charges_count.print_all_calculations()

female_age_calc = Calculations(female_age, 'female age')
#female_age_calc.print_all_calculations()
female_bmi_calc = Calculations(female_bmi, 'female BMI')
#female_bmi_calc.print_all_calculations()
female_children_calc = Calculations(female_children, 'female children')
#female_children_calc.print_all_calculations()
female_smokers_count = counting_smokers(female_smoker)
#print(female_smokers_count)
female_charges_count = Calculations(female_charges, 'female charges')
#female_charges_count.print_all_calculations()

##BMI calculations##
#Quartiles calculated outside the dataset: 1st quartile = 26.29/median = 30.4/3rd quartile = 34.7

lower_bmi = {}
lower_medium_bmi = {}
upper_medium_bmi = {}
upper_bmi = {}
def bmi_per_quartile(insurance_dictionary):
    for line in insurance_dictionary:
        data_bmi = float(insurance_dictionary[line]['BMI'])
        if data_bmi <= 26.29:
            lower_bmi.update({line: insurance_dictionary[line]})
        elif data_bmi > 26.29 and data_bmi <= 30.4:
            lower_medium_bmi.update({line: insurance_dictionary[line]})
        elif data_bmi > 30.4 and data_bmi <= 34.7:
            upper_medium_bmi.update({line: insurance_dictionary[line]})
        elif data_bmi > 34.7:
            upper_bmi.update({line: insurance_dictionary[line]})
    return lower_bmi, lower_medium_bmi, upper_medium_bmi, upper_bmi

lower_bmi, lower_medium_bmi, upper_medium_bmu, upper_bmi = bmi_per_quartile(insurance_dictionary)
#print(lower_bmi)
#print(lower_medium_bmi)
#print(upper_medium_bmi)
#print(upper_bmi)

#Lower BMI lists using RegionalLists:

lower_bmi_lists = RegionalLists(lower_bmi)
lower_bmi_age = lower_bmi_lists.get_age(lower_bmi)
#print(lower_bmi_age)
lower_bmi_children = lower_bmi_lists.get_children(lower_bmi)
lower_bmi_charges = lower_bmi_lists.get_charges(lower_bmi)
lower_bmi_sex = lower_bmi_lists.get_sex(lower_bmi)
lower_bmi_smoker = lower_bmi_lists.get_smokers(lower_bmi)
lower_bmi_region = lower_bmi_lists.get_region(lower_bmi)

#Lower BMI lists calculations:
#print(len(lower_bmi))
lower_bmi_age_calc = Calculations(lower_bmi_age, 'Lower BMI Age')
#lower_bmi_age_calc.print_all_calculations()
lower_bmi_children_calc = Calculations(lower_bmi_children, 'Lower BMI Children')
#lower_bmi_children_calc.print_all_calculations()
lower_bmi_charges_calc = Calculations(lower_bmi_charges, 'Lower BMI Charges')
#lower_bmi_charges_calc.print_all_calculations()
#print(region_count(lower_bmi_region))
#counting_sex(lower_bmi_sex)
#counting_smokers(lower_bmi_smoker)

#lower_medium BMI lists using RegionalLists:

lower_medium_bmi_lists = RegionalLists(lower_medium_bmi)
lower_medium_bmi_age = lower_medium_bmi_lists.get_age(lower_medium_bmi)
#print(lower_medium_bmi_age)
lower_medium_bmi_children = lower_medium_bmi_lists.get_children(lower_medium_bmi)
lower_medium_bmi_charges = lower_medium_bmi_lists.get_charges(lower_medium_bmi)
lower_medium_bmi_sex = lower_medium_bmi_lists.get_sex(lower_medium_bmi)
lower_medium_bmi_smoker = lower_medium_bmi_lists.get_smokers(lower_medium_bmi)
lower_medium_bmi_region = lower_medium_bmi_lists.get_region(lower_medium_bmi)

#lower_medium BMI lists calculations:
#print(len(lower_medium_bmi))
lower_medium_bmi_age_calc = Calculations(lower_medium_bmi_age, 'lower_medium BMI Age')
#lower_medium_bmi_age_calc.print_all_calculations()
lower_medium_bmi_children_calc = Calculations(lower_medium_bmi_children, 'lower_medium BMI Children')
#lower_medium_bmi_children_calc.print_all_calculations()
lower_medium_bmi_charges_calc = Calculations(lower_medium_bmi_charges, 'lower_medium BMI Charges')
#lower_medium_bmi_charges_calc.print_all_calculations()
#print(region_count(lower_medium_bmi_region))
#counting_sex(lower_medium_bmi_sex)
#counting_smokers(lower_medium_bmi_smoker)

#upper_medium BMI lists using RegionalLists:

upper_medium_bmi_lists = RegionalLists(upper_medium_bmi)
upper_medium_bmi_age = upper_medium_bmi_lists.get_age(upper_medium_bmi)
#print(upper_medium_bmi_age)
upper_medium_bmi_children = upper_medium_bmi_lists.get_children(upper_medium_bmi)
upper_medium_bmi_charges = upper_medium_bmi_lists.get_charges(upper_medium_bmi)
upper_medium_bmi_sex = upper_medium_bmi_lists.get_sex(upper_medium_bmi)
upper_medium_bmi_smoker = upper_medium_bmi_lists.get_smokers(upper_medium_bmi)
upper_medium_bmi_region = upper_medium_bmi_lists.get_region(upper_medium_bmi)

#upper_medium BMI lists calculations:
#print(len(upper_medium_bmi))
#upper_medium_bmi_age_calc = Calculations(upper_medium_bmi_age, 'upper_medium BMI Age')
#upper_medium_bmi_age_calc.print_all_calculations()
#upper_medium_bmi_children_calc = Calculations(upper_medium_bmi_children, 'upper_medium BMI Children')
#upper_medium_bmi_children_calc.print_all_calculations()
#upper_medium_bmi_charges_calc = Calculations(upper_medium_bmi_charges, 'upper_medium BMI Charges')
#upper_medium_bmi_charges_calc.print_all_calculations()
#print(region_count(upper_medium_bmi_region))
#counting_sex(upper_medium_bmi_sex)
#counting_smokers(upper_medium_bmi_smoker)

#upper BMI lists using RegionalLists:

upper_bmi_lists = RegionalLists(upper_bmi)
upper_bmi_age = upper_bmi_lists.get_age(upper_bmi)
#print(upper_bmi_age)
upper_bmi_children = upper_bmi_lists.get_children(upper_bmi)
upper_bmi_charges = upper_bmi_lists.get_charges(upper_bmi)
upper_bmi_sex = upper_bmi_lists.get_sex(upper_bmi)
upper_bmi_smoker = upper_bmi_lists.get_smokers(upper_bmi)
upper_bmi_region = upper_bmi_lists.get_region(upper_bmi)

#upper BMI lists calculations:
#print(len(upper_bmi))
#upper_bmi_age_calc = Calculations(upper_bmi_age, 'upper BMI Age')
#upper_bmi_age_calc.print_all_calculations()
#upper_bmi_children_calc = Calculations(upper_bmi_children, 'upper BMI Children')
#upper_bmi_children_calc.print_all_calculations()
#upper_bmi_charges_calc = Calculations(upper_bmi_charges, 'upper BMI Charges')
#upper_bmi_charges_calc.print_all_calculations()
#print(region_count(upper_bmi_region))
#counting_sex(upper_bmi_sex)
#counting_smokers(upper_bmi_smoker)

#print(sorted_charges)

##Charges calculations##
#Charges quartiles: Q1=4738.2682, Q2=9382.033, Q3=16657,71745

lower_charges = {}
lower_medium_charges = {}
upper_medium_charges = {}
upper_charges = {}

def charges_per_quartile(insurance_dictionary):
    for line in insurance_dictionary:
        data_charges = float(insurance_dictionary[line]['Charges'])
        if data_charges <= 4738.2682:
            lower_charges.update({line: insurance_dictionary[line]})
        elif data_charges > 4738.2682 and data_charges <= 9382.033:
            lower_medium_charges.update({line: insurance_dictionary[line]})
        elif data_charges > 9382.033 and data_charges <= 16657.71745:
            upper_medium_charges.update({line: insurance_dictionary[line]})
        elif data_charges > 16657.71745:
            upper_charges.update({line: insurance_dictionary[line]})
    return lower_charges, lower_medium_charges, upper_medium_charges, upper_charges

lower_charges, lower_medium_charges, upper_medium_charges, upper_charges = charges_per_quartile(insurance_dictionary)
#print(lower_charges)
#print(len(lower_charges))

#Lower charges lists using RegionalLists:

lower_charges_lists = RegionalLists(lower_charges)
lower_charges_age = lower_charges_lists.get_age(lower_charges)
#print(lower_charges_age)
lower_charges_children = lower_charges_lists.get_children(lower_charges)
lower_charges_bmi = lower_charges_lists.get_bmi(lower_bmi)
lower_charges_sex = lower_charges_lists.get_sex(lower_charges)
lower_charges_smoker = lower_charges_lists.get_smokers(lower_charges)
lower_charges_region = lower_charges_lists.get_region(lower_charges)

#Lower charges lists calculations:
#print(len(lower_charges))
#lower_charges_age_calc = Calculations(lower_charges_age, 'Lower charges Age')
#lower_charges_age_calc.print_all_calculations()
#lower_charges_children_calc = Calculations(lower_charges_children, 'Lower charges Children')
#lower_charges_children_calc.print_all_calculations()
#lower_charges_bmi_calc = Calculations(lower_charges_bmi, 'Lower charges BMI')
#lower_charges_bmi_calc.print_all_calculations()
#print(region_count(lower_charges_region))
#counting_sex(lower_charges_sex)
#counting_smokers(lower_charges_smoker)

#lower_medium charges lists using RegionalLists:

lower_medium_charges_lists = RegionalLists(lower_medium_charges)
lower_medium_charges_age = lower_medium_charges_lists.get_age(lower_medium_charges)
#print(lower_medium_charges_age)
lower_medium_charges_children = lower_medium_charges_lists.get_children(lower_medium_charges)
lower_medium_charges_bmi = lower_medium_charges_lists.get_bmi(lower_medium_bmi)
lower_medium_charges_sex = lower_medium_charges_lists.get_sex(lower_medium_charges)
lower_medium_charges_smoker = lower_medium_charges_lists.get_smokers(lower_medium_charges)
lower_medium_charges_region = lower_medium_charges_lists.get_region(lower_medium_charges)

#lower_medium charges lists calculations:
#print(len(lower_medium_charges))
#lower_medium_charges_age_calc = Calculations(lower_medium_charges_age, 'lower_medium charges Age')
#lower_medium_charges_age_calc.print_all_calculations()
#lower_medium_charges_children_calc = Calculations(lower_medium_charges_children, 'lower_medium charges Children')
#lower_medium_charges_children_calc.print_all_calculations()
#lower_medium_charges_bmi_calc = Calculations(lower_medium_charges_bmi, 'lower_medium charges BMI')
#lower_medium_charges_bmi_calc.print_all_calculations()
#print(region_count(lower_medium_charges_region))
#counting_sex(lower_medium_charges_sex)
#counting_smokers(lower_medium_charges_smoker)

#upper_medium charges lists using RegionalLists:

upper_medium_charges_lists = RegionalLists(upper_medium_charges)
upper_medium_charges_age = upper_medium_charges_lists.get_age(upper_medium_charges)
#print(upper_medium_charges_age)
upper_medium_charges_children = upper_medium_charges_lists.get_children(upper_medium_charges)
upper_medium_charges_bmi = upper_medium_charges_lists.get_bmi(upper_medium_bmi)
upper_medium_charges_sex = upper_medium_charges_lists.get_sex(upper_medium_charges)
upper_medium_charges_smoker = upper_medium_charges_lists.get_smokers(upper_medium_charges)
upper_medium_charges_region = upper_medium_charges_lists.get_region(upper_medium_charges)

#upper_medium charges lists calculations:
#print(len(upper_medium_charges))
#upper_medium_charges_age_calc = Calculations(upper_medium_charges_age, 'upper_medium charges Age')
#upper_medium_charges_age_calc.print_all_calculations()
#upper_medium_charges_children_calc = Calculations(upper_medium_charges_children, 'upper_medium charges Children')
#upper_medium_charges_children_calc.print_all_calculations()
#upper_medium_charges_bmi_calc = Calculations(upper_medium_charges_bmi, 'upper_medium charges BMI')
#upper_medium_charges_bmi_calc.print_all_calculations()
#print(region_count(upper_medium_charges_region))
#counting_sex(upper_medium_charges_sex)
#counting_smokers(upper_medium_charges_smoker)

#upper charges lists using RegionalLists:

upper_charges_lists = RegionalLists(upper_charges)
upper_charges_age = upper_charges_lists.get_age(upper_charges)
#print(upper_charges_age)
upper_charges_children = upper_charges_lists.get_children(upper_charges)
upper_charges_bmi = upper_charges_lists.get_bmi(upper_bmi)
upper_charges_sex = upper_charges_lists.get_sex(upper_charges)
upper_charges_smoker = upper_charges_lists.get_smokers(upper_charges)
upper_charges_region = upper_charges_lists.get_region(upper_charges)

#upper charges lists calculations:
#print(len(upper_charges))
upper_charges_age_calc = Calculations(upper_charges_age, 'upper charges Age')
upper_charges_age_calc.print_all_calculations()
upper_charges_children_calc = Calculations(upper_charges_children, 'upper charges Children')
upper_charges_children_calc.print_all_calculations()
upper_charges_bmi_calc = Calculations(upper_charges_bmi, 'upper charges BMI')
upper_charges_bmi_calc.print_all_calculations()
#print(region_count(upper_charges_region))
#counting_sex(upper_charges_sex)
counting_smokers(upper_charges_smoker)

#children calculations#
#dict categories per children
zero_children = {}
one_children = {}
two_children = {}
three_children = {}
four_children = {}
five_children = {}

def children_dictionary(insurance_dictionary):
    for i in insurance_dictionary:
        children = insurance_dictionary[i]['Children']
        current_i = insurance_dictionary[i]        
        if children == '0':
            zero_children.update({i: insurance_dictionary[i]})
        elif children == '1':
            one_children.update({i: insurance_dictionary[i]})
        elif children == '2':
            two_children.update({i: insurance_dictionary[i]})
        elif children == '3':
            three_children.update({i: insurance_dictionary[i]})
        elif children == '4':
            four_children.update({i: insurance_dictionary[i]})
        elif children == '5':
            five_children.update({i: insurance_dictionary[i]})
    return zero_children, one_children, two_children, three_children, four_children, five_children

zero_children, one_children, two_children, three_children, four_children, five_children = children_dictionary(insurance_dictionary)
#print(zero_children)
#print(len(zero_children))
#print(len(one_children))
#print(len(two_children))
#print(len(three_children))
#print(len(four_children))
#print(len(five_children))

#Zero children data lists:
zero_calculations = RegionalLists(zero_children)
zero_bmi = sorted(zero_calculations.get_bmi(zero_children))
#print(zero_bmi)
zero_age = sorted(zero_calculations.get_age(zero_children))
#print(zero_age)
zero_charges = sorted(zero_calculations.get_charges(zero_children), key=float)
#print(zero_charges)
zero_smokers = zero_calculations.get_smokers(zero_children)
#print(zero_smokers)
zero_sex = zero_calculations.get_sex(zero_children)
#print(zero_sex)
zero_regions = zero_calculations.get_region(zero_children)

#One child data lists
one_calculations = RegionalLists(one_children)
one_bmi = sorted(one_calculations.get_bmi(one_children))
#print(one_bmi)
one_age = sorted(one_calculations.get_age(one_children))
#print(one_age)
one_charges = sorted(one_calculations.get_charges(one_children), key=float)
#print(one_charges)
one_smokers = one_calculations.get_smokers(one_children)
#print(one_smokers)
one_sex = one_calculations.get_sex(one_children)
#print(one_sex)
one_regions = one_calculations.get_region(one_children)

#two child data lists
two_calculations = RegionalLists(two_children)
two_bmi = sorted(two_calculations.get_bmi(two_children))
#print(two_bmi)
two_age = sorted(two_calculations.get_age(two_children))
#print(two_age)
two_charges = sorted(two_calculations.get_charges(two_children), key=float)
#print(two_charges)
two_smokers = two_calculations.get_smokers(two_children)
#print(two_smokers)
two_sex = two_calculations.get_sex(two_children)
#print(two_sex)
two_regions = two_calculations.get_region(two_children)

#three child data lists
three_calculations = RegionalLists(three_children)
three_bmi = sorted(three_calculations.get_bmi(three_children))
#print(three_bmi)
three_age = sorted(three_calculations.get_age(three_children))
#print(three_age)
three_charges = sorted(three_calculations.get_charges(three_children), key=float)
#print(three_charges)
three_smokers = three_calculations.get_smokers(three_children)
#print(three_smokers)
three_sex = three_calculations.get_sex(three_children)
#print(three_sex)
three_regions = three_calculations.get_region(three_children)

#four child data lists
four_calculations = RegionalLists(four_children)
four_bmi = sorted(four_calculations.get_bmi(four_children))
#print(four_bmi)
four_age = sorted(four_calculations.get_age(four_children))
#print(four_age)
four_charges = sorted(four_calculations.get_charges(four_children), key=float)
#print(four_charges)
four_smokers = four_calculations.get_smokers(four_children)
#print(four_smokers)
four_sex = four_calculations.get_sex(four_children)
#print(four_sex)
four_regions = four_calculations.get_region(four_children)

#five child data lists
five_calculations = RegionalLists(five_children)
five_bmi = sorted(five_calculations.get_bmi(five_children))
#print(five_bmi)
five_age = sorted(five_calculations.get_age(five_children))
#print(five_age)
five_charges = sorted(five_calculations.get_charges(five_children), key=float)
#print(five_charges)
five_smokers = five_calculations.get_smokers(five_children)
#print(five_smokers)
five_sex = five_calculations.get_sex(five_children)
#print(five_sex)
five_regions = five_calculations.get_region(five_children)

#age calculations per number of children:
zero_age_calculations = Calculations(zero_age, "Zero children age")
#zero_age_calculations.print_all_calculations()
one_age_calculations = Calculations(one_age, "one children age")
#one_age_calculations.print_all_calculations()
two_age_calculations = Calculations(two_age, "two children age")
#two_age_calculations.print_all_calculations()
three_age_calculations = Calculations(three_age, "three children age")
#three_age_calculations.print_all_calculations()
four_age_calculations = Calculations(four_age, "four children age")
#four_age_calculations.print_all_calculations()
five_age_calculations = Calculations(five_age, "five children age")
#five_age_calculations.print_all_calculations()

#BMI calculations per number of children:
zero_bmi_calculations = Calculations(zero_bmi, "Zero children bmi")
#zero_bmi_calculations.print_all_calculations()
one_bmi_calculations = Calculations(one_bmi, "one children bmi")
#one_bmi_calculations.print_all_calculations()
two_bmi_calculations = Calculations(two_bmi, "two children bmi")
#two_bmi_calculations.print_all_calculations()
three_bmi_calculations = Calculations(three_bmi, "three children bmi")
#three_bmi_calculations.print_all_calculations()
four_bmi_calculations = Calculations(four_bmi, "four children bmi")
#four_bmi_calculations.print_all_calculations()
five_bmi_calculations = Calculations(five_bmi, "five children bmi")
#five_bmi_calculations.print_all_calculations()

#Charges calculations per number of children:
zero_charges_calculations = Calculations(zero_charges, "Zero children charges")
#zero_charges_calculations.print_all_calculations()
one_charges_calculations = Calculations(one_charges, "one children charges")
#one_charges_calculations.print_all_calculations()
two_charges_calculations = Calculations(two_charges, "two children charges")
#two_charges_calculations.print_all_calculations()
three_charges_calculations = Calculations(three_charges, "three children charges")
#three_charges_calculations.print_all_calculations()
four_charges_calculations = Calculations(four_charges, "four children charges")
#four_charges_calculations.print_all_calculations()
five_charges_calculations = Calculations(five_charges, "five children charges")
#five_charges_calculations.print_all_calculations()

#Sex per number of children:
#zero_sex_data = counting_sex(zero_sex)
#one_sex_data = counting_sex(one_sex)
#two_sex_data = counting_sex(two_sex)
#three_sex_data = counting_sex(three_sex)
#four_sex_data = counting_sex(four_sex)
#five_sex_data = counting_sex(five_sex)

#Smokers per number of children:
#print(counting_smokers(zero_smokers))
#print(counting_smokers(one_smokers))
#print(counting_smokers(two_smokers))
#print(counting_smokers(three_smokers))
#print(counting_smokers(four_smokers))
#print(counting_smokers(five_smokers))

#Number of children per region:
#print(region_count(zero_regions))
#print(region_count(one_regions))
#print(region_count(two_regions))
#print(region_count(three_regions))
#print(region_count(four_regions))
#print(region_count(five_regions))

###Smokers calculations###
smoker = {}
non_smoker = {}

def smoking_status(insurance_dictionary):    
    for rank in insurance_dictionary:
        smoke = insurance_dictionary[rank]['Smoker']  
        if smoke == 'yes':
            smoker.update({rank: insurance_dictionary[rank]})
        elif smoke == 'no':
            non_smoker.update({rank: insurance_dictionary[rank]})
    return smoker, non_smoker

smoker, non_smoker = smoking_status(insurance_dictionary)
#print(smoker)
#len(smoker)

#Data lists for smokers
smoker_lists = RegionalLists(smoker)
smoker_age = smoker_lists.get_age(smoker)
#print(smoker_age)
sorted_smoker_age = sorted(smoker_age)
#print(sorted_smoker_age)
smoker_bmi = sorted(smoker_lists.get_bmi(smoker), key=float)
smoker_children = sorted(smoker_lists.get_children(smoker))
smoker_sex = smoker_lists.get_sex(smoker)
smoker_region = smoker_lists.get_region(smoker)
smoker_charges = sorted(smoker_lists.get_charges(smoker), key=float)

#Data lists for non-smokers
non_smoker_lists = RegionalLists(non_smoker)
non_smoker_age = non_smoker_lists.get_age(non_smoker)
#print(non_smoker_age)
sorted_non_smoker_age = sorted(non_smoker_age)
#print(sorted_non_smoker_age)
non_smoker_bmi = sorted(non_smoker_lists.get_bmi(non_smoker), key=float)
non_smoker_children = sorted(non_smoker_lists.get_children(non_smoker))
non_smoker_sex = non_smoker_lists.get_sex(non_smoker)
non_smoker_region = non_smoker_lists.get_region(non_smoker)
non_smoker_charges = sorted(non_smoker_lists.get_charges(non_smoker), key=float)

#Calculations for smokers and non-smokers:
smoker_age_calc = Calculations(smoker_age, 'smoker age')
#smoker_age_calc.print_all_calculations()
smoker_bmi_calc = Calculations(smoker_bmi, 'smoker BMI')
#smoker_bmi_calc.print_all_calculations()
smoker_children_calc = Calculations(smoker_children, 'smoker children')
#smoker_children_calc.print_all_calculations()
#smokers_sex_count = counting_sex(smoker_sex)
smoker_charges_count = Calculations(smoker_charges, 'smoker charges')
#smoker_charges_count.print_all_calculations()

non_smoker_age_calc = Calculations(non_smoker_age, 'non_smoker age')
#non_smoker_age_calc.print_all_calculations()
non_smoker_bmi_calc = Calculations(non_smoker_bmi, 'non_smoker BMI')
#non_smoker_bmi_calc.print_all_calculations()
non_smoker_children_calc = Calculations(non_smoker_children, 'non_smoker children')
#non_smoker_children_calc.print_all_calculations()
#non_smokers_sex_count = counting_sex(non_smoker_sex)
non_smoker_charges_count = Calculations(non_smoker_charges, 'non_smoker charges')
#non_smoker_charges_count.print_all_calculations()

#print(sorted_age)

##Age by quartile##
##Quartile calculator: 1st = 27, median = 39, 3rd = 51

lower_age = {}
lower_medium_age = {}
upper_medium_age = {}
upper_age = {}

def age_per_quartile(insurance_dictionary):
    for line in insurance_dictionary:
        data_age = float(insurance_dictionary[line]['Age'])
        if data_age <= 27:
            lower_age.update({line: insurance_dictionary[line]})
        elif data_age > 27 and data_age <= 39:
            lower_medium_age.update({line: insurance_dictionary[line]})
        elif data_age > 39 and data_age <= 51:
            upper_medium_age.update({line: insurance_dictionary[line]})
        elif data_age > 51:
            upper_age.update({line: insurance_dictionary[line]})
    return lower_age, lower_medium_age, upper_medium_age, upper_age

lower_age, lower_medium_age, upper_medium_age, upper_age = age_per_quartile(insurance_dictionary)

#Lower age lists using RegionalLists:

lower_age_lists = RegionalLists(lower_age)
lower_age_charges = lower_age_lists.get_charges(lower_age)
#print(lower_age_age)
lower_age_children = lower_age_lists.get_children(lower_age)
lower_age_bmi = lower_age_lists.get_bmi(lower_bmi)
lower_age_sex = lower_age_lists.get_sex(lower_age)
lower_age_smoker = lower_age_lists.get_smokers(lower_age)
lower_age_region = lower_age_lists.get_region(lower_age)

#Lower age lists calculations:
#print(len(lower_age))
lower_age_charges_calc = Calculations(lower_age_charges, 'Lower age charges')
#lower_age_charges_calc.print_all_calculations()
lower_age_children_calc = Calculations(lower_age_children, 'Lower age Children')
#lower_age_children_calc.print_all_calculations()
lower_age_bmi_calc = Calculations(lower_age_bmi, 'Lower age BMI')
#lower_age_bmi_calc.print_all_calculations()
#print(region_count(lower_age_region))
#counting_sex(lower_age_sex)
print(counting_smokers(lower_age_smoker))

#lower_medium age lists using RegionalLists:

lower_medium_age_lists = RegionalLists(lower_medium_age)
lower_medium_age_charges = lower_medium_age_lists.get_charges(lower_medium_age)
lower_medium_age_children = lower_medium_age_lists.get_children(lower_medium_age)
lower_medium_age_bmi = lower_medium_age_lists.get_bmi(lower_medium_bmi)
lower_medium_age_sex = lower_medium_age_lists.get_sex(lower_medium_age)
lower_medium_age_smoker = lower_medium_age_lists.get_smokers(lower_medium_age)
lower_medium_age_region = lower_medium_age_lists.get_region(lower_medium_age)

#lower_medium age lists calculations:
#print(len(lower_medium_age))
lower_medium_age_charges_calc = Calculations(lower_medium_age_charges, 'lower_medium age charges')
#lower_medium_age_charges_calc.print_all_calculations()
lower_medium_age_children_calc = Calculations(lower_medium_age_children, 'lower_medium age Children')
#lower_medium_age_children_calc.print_all_calculations()
lower_medium_age_bmi_calc = Calculations(lower_medium_age_bmi, 'lower_medium age BMI')
#lower_medium_age_bmi_calc.print_all_calculations()
#print(region_count(lower_medium_age_region))
#counting_sex(lower_medium_age_sex)
#print(counting_smokers(lower_medium_age_smoker))

#upper_medium age lists using RegionalLists:

upper_medium_age_lists = RegionalLists(upper_medium_age)
upper_medium_age_charges = upper_medium_age_lists.get_charges(upper_medium_age)
#print(upper_medium_age_charges)
upper_medium_age_children = upper_medium_age_lists.get_children(upper_medium_age)
upper_medium_age_bmi = upper_medium_age_lists.get_bmi(upper_medium_bmi)
upper_medium_age_sex = upper_medium_age_lists.get_sex(upper_medium_age)
upper_medium_age_smoker = upper_medium_age_lists.get_smokers(upper_medium_age)
upper_medium_age_region = upper_medium_age_lists.get_region(upper_medium_age)

#upper_medium age lists calculations:
#print(len(upper_medium_age))
upper_medium_age_charges_calc = Calculations(upper_medium_age_charges, 'upper_medium age charges')
#upper_medium_age_charges_calc.print_all_calculations()
upper_medium_age_children_calc = Calculations(upper_medium_age_children, 'upper_medium age Children')
#upper_medium_age_children_calc.print_all_calculations()
upper_medium_age_bmi_calc = Calculations(upper_medium_age_bmi, 'upper_medium age BMI')
#upper_medium_age_bmi_calc.print_all_calculations()
#print(region_count(upper_medium_age_region))
#counting_sex(upper_medium_age_sex)
#print(counting_smokers(upper_medium_age_smoker))

#upper age lists using RegionalLists:

upper_age_lists = RegionalLists(upper_age)
upper_age_charges = upper_age_lists.get_charges(upper_age)
#print(upper_age_charges)
upper_age_children = upper_age_lists.get_children(upper_age)
upper_age_bmi = upper_age_lists.get_bmi(upper_bmi)
upper_age_sex = upper_age_lists.get_sex(upper_age)
upper_age_smoker = upper_age_lists.get_smokers(upper_age)
upper_age_region = upper_age_lists.get_region(upper_age)

#upper age lists calculations:
#print(len(upper_age))
upper_age_charges_calc = Calculations(upper_age_charges, 'upper age charges')
#upper_age_charges_calc.print_all_calculations()
upper_age_children_calc = Calculations(upper_age_children, 'upper age Children')
#upper_age_children_calc.print_all_calculations()
upper_age_bmi_calc = Calculations(upper_age_bmi, 'upper age BMI')
#upper_age_bmi_calc.print_all_calculations()
#print(region_count(upper_age_region))
#counting_sex(upper_age_sex)
#print(counting_smokers(upper_age_smoker))
# Out:
# This dataset has a upper charges Age minimum of 18.0, a maximum of 64.0 and an average of 40.
# This dataset has a upper charges Children minimum of 0.0, a maximum of 5.0 and an average of 1.
# This dataset has a upper charges BMI minimum of 17.765, a maximum of 52.58 and an average of 31.
# There are 77 smokers over 362 people, or 21 per cent.
